# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/databases/blob/main/10_About_NoSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Last amended: 24th June, 2024
# Myfolder:
# Objective: About NoSQL Databases

# %% [markdown]
# # NoSQL Databases

# %% [markdown]
# A typical SQL database is <b>difficult to scale horizontally</b>. It cannot be broken on links with one table in one Server and another on another server. This will create problems of speed, availability (what if one server with one of the linked tables is down), replication and scalability. Refer [Microsoft Sales SQL tracker](https://www.dbdesigner.net/microsoft-sql-database-design-template/).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# NoSQL database provides storage and retrieval of data that is modeled other than as Relational tables. These are increasingly being used in the age of Web2.0 and are also called 'Not only SQL' that is they may have SQL like query language besides other. Today in the age of polyglot persistence NoSQL databases are one of the many databases that companies use.

# %% [markdown]
# SQL databases <b>schema can be rigid</b> and difficult to change. For example, in a schema of [College Admission Form](https://github.com/dipskr/FDBMS) , suppose one  decides to add a column in the <i>Departments</i> table named as: <i>SubjectsTaught</i>. And also decide to make this column NOT NULL with DEFAULT constraint (having a default value of '<i>Statistics</i>').

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here are the two tables: <b>Original</b> and <b>Desired</b>. If we create the desired table, what happens to values in earlier rows? What if the existing number of rows are already in millions (say, in a banking system or in a Railway reservation system)?
#
# The problem may become more complicated, if we were to bring in a 'Year' column--per department, <i>'No of faculties'</i> may change 'Year'-wise. In that case both <i>'Year'</i> and <i>'ID'</i> will become composite primary key.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SQL databases are also <b>unfit for performing analytics</b> on data even when they may reside on one server. Data needed for a machine learning operation may be residing in two or more tables. ML operatons require a huge number of iterations on data. And, at each iteration data may have to be extracted from linked tables and worked upon. This can be very time consuming (even if relevant tables are allowed to reside in memory).

# %% [markdown]
# SQL tables are also <b>unfit for streaming writes</b>. Incoming data (such as <i>Weather or uber car location or inventory level</i> data) may have to be written to many tables. This will involve delay.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Polyglot Persistence<br>
# Ref [here](https://martinfowler.com/bliki/PolyglotPersistence.html)

# %% [markdown]
# Polyglot persistence shares its origins with how the term Polyglot programming is defined. Polyglot programming is a term coined by Neal Ford in 2006, and expresses the idea that computer applications should be written in a mix of different programming languages, in order to take advantage of the fact that different languages are suitable for tackling different problems. Complex applications combine different types of problems, so picking the right language for each job may be more productive than trying to solve all aspects of the problem using a single language.

# %% [markdown]
# A *polyglot* is a person who is gifted in languages. A polyglot can speak at least four languages and usually understand more. For polyglot programming please see [here](http://memeagora.blogspot.com/2006/12/polyglot-programming.html). A simple example of polyglot programming is when you use google colab. You are using:
# * python to write ML programs
# * bash script to install package(s)
# * Jupyter markdown or html for text formatting

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For an e-commerce organization, here are the choices:
# * Store financial transactions--Use RDBMS
# * Store Session cache--Use Redis
# * Store comments--Use mongodb
# * Store Discussion forum--Use Cassendra
# * Serve advertisement--Use Riak
# * Perform analytics--Use mongodb
# * Recommender engine--Graph databases

# %% [markdown]
# ### Points of diffferences

# %% [markdown]
# Points of differences between various NoSQL databases can be very fine, making choices difficult.
#
# * Types of data-structures that can be stored
# * Cache vs persistent stores
# * High scalability along with high availability but simpler data-structures
# * Very fast replication
# * Very fast indexing and queries (but simpler queries)
# * Complex querying ability
# * Ability to query on keys vs ability to query on fields
# * Can perform complex analytics on data
# * Can discover relationships
# * Read/Write performance Faster Read / Faster Write
# * Streaming data and time series data

# %% [markdown]
# Redis is in-memory database or cache with limited scalability. It is very fast with a rich set of in-memory data-structures. It is ideal for storing session data. Redis data structures are strings, sets, sorted-sets, lists, hashes, bitmaps and bitfields. Read [here](https://redis.com/redis-enterprise/data-structures/) for Redis data structures. For Redsi hash, see [here](https://redisson.org/glossary/redis-hash.html).
#
#
#  Riak is <u>*highly available*</u>, scalable, persistent key-value database with a *focus on data-integrity*. Unlike, Redis it is not in memory and does have some latency. Riak’s data model and architecture emphasize high availability at the cost of strong consistency. What this means in practice is that the database remains up for writes and reads regardless of severe network and machine failures, however the correctness of your data during periods of duress will be inconsistent. For some applications this is a useful thing (if you’re collecting metrics for analysis,  It is very appropriate for shopping-carts and user-profiles. Please see this StackOverflow [link](https://stackoverflow.com/a/37148910) on the difference between the two. Please note that while NoSQL databases may be highly available, data-consistency may be lacking. Riak is often a good choice for serving advertising content to many different web and mobile users simultaneously with low latency. It can also be used for storing real-time log data (a 'bucket' of data) for quick analysis or for storing real-time sensor data. See [here](https://docs.riak.com/riak/kv/latest/learn/use-cases/index.html) for Riak use cases.
# Cassandra is a wide-column NoSQL database appropriate for storing web-pages or tweets or logs over a long-term.

# %% [markdown]
# ## Motivations for NoSQL databases

# %% [markdown]
# 1. Simplicity of system design--No normalizations
# 2. Schema less
# 3. Simpler horizontal scaling to cluster of machines. *Generally* (as against '*always*') available
# 4. Unstructured data (or every type of data) can be stored

# %% [markdown]
# ## Against NoSQL databases

# %% [markdown]
# 1. Query language is quite difficult.
# 2. Not suitable for transactions as in finance or banking
# 3. Some nosql system may have write data loss while many others provide Write-Ahead-logging to prevent dataloss.
# 4. No standard DDL, DML or Data access language
# 5. Moving database from one system (say, MongoDb) to another (say, OrientDB or CouchDB) is difficult.

# %% [markdown]
# ## Types of NoSQL databases

# %% [markdown]
# ### key-value Cache

# %% [markdown]
# Redis is an in memory data-structure store. Data structures can be simple values, lists, capped-lists, sets, sorted-sets, maps and so on.  Usage: Session cache, full-page cache, leaderboards, shared games status. Memcached and couchbase are two other examples.

# %% [markdown]
# ### Key value store

# %% [markdown]
# Examples: Riak and voldemort. The biggest difference between Riak and Redis is the "typical usage" for each. Redis is typically used as a high-speed in-memory cache for applications, whereas Riak is typically used as a scalable highly available persistent data store / database. Riak, like redis also has certain data-structures suited for specific purposes. See [this link](https://docs.riak.com/riak/kv/2.2.3/developing/data-types.1.html) for Riak Data Types. See this [link](https://docs.riak.com/riak/kv/latest/learn/use-cases/index.html) for Riak use cases. For example, while both Redis and Riak may be used for Session Storage, Riak distiguishes itself for the type of operations and analytics one can perform on Session Storage.

# %% [markdown]
# ### Document Databases

# %% [markdown]
# A document-oriented database, or document store, is a computer program and data storage system designed for storing, retrieving and managing document-oriented information, also known as semi-structured data.
#
# Document-oriented databases are one of the main categories of NoSQL databases, and the popularity of the term "document-oriented database" has grown with the use of the term NoSQL itself. XML databases are a subclass of document-oriented databases that are optimized to work with XML documents.
#
# In some sense graph databases can be thought of as Document Databases with an <u>additional relationship layer</u> that links documents. Here documents are nodes and relationships are edges. Examples: Documentdb, Mongodb, Elasticsearch

# %% [markdown]
# #### Riak vs Mongodb

# %% [markdown]
# Both Riak and Mongodb are vastly different: While both fit under the NoSQL document umbrella, Riak is a key-value store, with a lot of emphasis on <u>*replication* and *low maintenance* </u>.
#
# MongoDB allows complex *query on arbitrary fields*, but *doesn't put as much focus on replication*.
# Basically: if you only do key-value queries, Riak is a good (great) alternative. If you ever do (in pseudo SQL speak:) Select * where item.name="Martijn" you will need a lot more code (building your own indexes etc) to do this on stock Riak, while MongoDB supports these queries.

# %% [markdown]
# ### Graph Databases

# %% [markdown]
# Graph databases are purpose-built to store and navigate relationships. Relationships are first-class citizens in graph databases, and most of the value of graph databases is derived from these relationships. Graph databases use nodes to store data entities, and edges to store relationships between entities. An edge always has a start node, end node, type, and direction, and an edge can describe parent-child relationships, actions, ownership, and the like. There is no limit to the number and kind of relationships a node can have.
# A graph in a graph database can be traversed along specific edge types or across the entire graph. In graph databases, traversing the joins or relationships is very fast because the relationships between nodes are not calculated at query times but are persisted in the database. Graph databases have advantages for use cases such as networking (social, roads, railways), recommendation engines (using a network of products purchased) and fraud detection, when you need to create relationships between data and quickly query these relationships.

# %% [markdown]
# How to find friend of friend of friend in the following table:
#
# | u_name | friendName | age |
# | --- | --- | --- |
# | ashok | amit | 28 |
# | amit | abhishek | 38 |
# | abhishek | kavita | 32 |
#
# Join the table with itself on the field <i>friendName</i> of one table and <i>u_name</i> of another table. It will answer the query:
# > <i>select friendOfFriend where u_name = 'ashok'</i>
#
# | u_name | friendName | age | friendOfFriend | age1 |
# | --- | --- | --- | --- | --- |
# | ashok | amit | 28 | ahishek | 38 |
# | amit | abhishek | 38 | kavita | 32 |
# | abhishek | kavita | 32 |
#
# Join the result table again with itself: <i>friendOfFriend</i> of one table and <i>u_name</i> of another table.
# > <i>select friendOfFriend, friendOfFriendOfFriend  where u_name = 'ashok'</i>
#
# | u_name | friendName | age | friendOfFriend | age1 | friendOfFriendOfFriend | age2 |
# | --- | --- | --- | --- | --- | --- | --- |
# | ashok | amit | 28 | ahishek | 38 | kavita | 32
# | amit | abhishek | 38 |
# | abhishek | kavita | 32 |

# %% [markdown]
# The following graph shows an example of a social network graph. Given the people (nodes) and their relationships (edges), you can find out who the "friends of friends" of a particular person are—for example, the friends of Howard's friends.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here is a demo-graph for a recommender engine. Which Resturant should one vist for which food?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A graph can have multiple types of nodes and multiple types of relationships.
#
# *    A vertex (or node) represents an entity, such as a person or restaurant. In your graph, you have three types of vertex: customers, restaurants, and the type of cuisine served (called genre in the code examples).
# *    An edge defines a relationship between two vertices. For example, a customer might visit a restaurant or a restaurant may serve food of a particular cuisine. An edge always has direction – it will be outgoing from one vertex and incoming to the other.
# *    A property is a key-value pair that enriches a vertex or an edge. For example, a customer has a name or the customer might rate their experience when they visit a restaurant.

# %% [markdown]
# Similary a recommendation engine for Movies can have many kinds of nodes and relationships. For example in the MovieLens dataset, it can be represented in the form of a very simple graph, with :
#
# > three kinds of nodes: <br>
# >> User <br>
# >> Movie <br>
# >> Genre <br>
#
# > two kinds of edges :
# >> Has_rated : If user ui has rated movie mj, then ui is explicitly linked with mj, with a relation of type Has_rated. The rating r(mj,ui) is recorded as a property of the edge. <br>
# >> Is_genre : If movie mj belongs to genre gi, then mj is explicitly linked with gi, with a relation of type Is_genre.<br>

# %% [markdown]
# Here is another graph database displaying relationships between Movies, Director and Actors

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As of 2021, no universal graph query language has been adopted in the same way as SQL was for relational databases, and there are a wide variety of systems, most often tightly tied to one product.

# %% [markdown]
# ### Wide Column databases
# See [here](https://stackoverflow.com/a/62027444) and this [link](https://www.kdnuggets.com/2021/02/understanding-nosql-database-types-column-oriented-databases.html) on KDnuggets.

# %% [markdown]
# Wide-column stores such as Bigtable and Apache Cassandra are not column stores in the original sense of the term, since their two-level structures do not use a columnar data layout. In genuine column stores, a columnar data layout is adopted such that each column is stored separately on disk. Wide-column stores do often support the <u>*notion of column families*</u> that are stored separately. However, each such column family typically contains multiple columns that are used together, similar to traditional relational database tables. Within a given column family, all data is stored in a row-by-row fashion, such that the columns for a given row are stored together, rather than each column being stored separately. Wide-column stores that support column families are also known as column family databases. Examples: BigTable, Hbase, Cassandra.

# %% [markdown]
# #### How is data stored?

# %% [markdown]
# Wide-column stores do often support the notion of column families that are stored separately (as different files). However, each such column family typically contains multiple columns that are used together, similar to traditional relational database tables. Within a given column family, all data is stored in a row-by-row fashion, such that the columns for a given row are stored together, rather than each column being stored separately. (See this [link](https://stackoverflow.com/a/38793843) on StackOverflow.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Looking above, we can see that a wide-column store can be interpreted as a <u>two-dimensional</u> key–value store. One key is Row-id and another key is Column Family Name.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# User proflie is a column family. Note that each row may contain different sets of columns. Examples of column families are: Product information, Sales Order information, Supplier information etc

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### How is data stored

# %% [markdown]
# Wide-column stores do often support the notion of column families that are stored separately (as different files). However, each such column family typically contains multiple columns that are used together, similar to traditional relational database tables. Within a given column family, all data is stored in a row-by-row fashion, such that the columns for a given row are stored together, rather than each column being stored separately. (See this [link](https://stackoverflow.com/a/38793843) and this [link](https://stackoverflow.com/a/17838013) on StackOverflow and also see this [link](http://dbmsmusings.blogspot.com/2010/03/distinguishing-two-major-types-of_29.html).)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Columnar data storage
# See [here](https://en.wikipedia.org/wiki/Column-oriented_DBMS)

# %% [markdown]
# It is common in many NoSQL databases to store data column-wise rather than row-wise. Here is a table:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# RowId is given by the system when storage is row-wise. Typical row-wise storage would be:

# %% [markdown]
#
# 001:10,Smith,Joe,60000;
# 002:12,Jones,Mary,80000;
# 003:11,Johnson,Cathy,94000;
# 004:22,Jones,Bob,55000;

# %% [markdown]
# Row-oriented systems are designed to efficiently return data for an entire row, or record, in as few operations as possible. This matches the common use-case where the system is attempting to retrieve information about a particular object, say the contact information for a user.
#
# However, let us say, query on Salary are commomn. In order to find all records in the example table with salaries between 40,000 and 50,000, the DBMS would have to fully scan through the entire table looking for matching records.

# %% [markdown]
# A column-oriented database serializes all of the values of a column together, then the values of the next column, and so on. For our example table, the data would be stored in this fashion:

# %% [markdown]
# 10:001,12:002,11:003,22:004;
# Smith:001,Jones:002,Johnson:003,Jones:004;
# Joe:001,Mary:002,Cathy:003,Bob:004;
# 60000:001,80000:002,94000:003,55000:004;

# %% [markdown]
# In this database, it will be very fast to answer any query on Salary.

# %% [markdown]
# ## Handling relational data

# %% [markdown]
# Tabl joins are not easy in NoSQL databases. If, therefore, relational databases are to be stored one has to adopt either or more of following strategies.

# %% [markdown]
# ### Multiple Queries

# %% [markdown]
# Instead of retrieving all the data with one query, it is common to do several queries to get the desired data. NoSQL queries are often faster than traditional SQL queries so the cost of additional queries may be acceptable. If an excessive number of queries would be necessary, one of the other of the following two approaches is more appropriate.

# %% [markdown]
# ### No foreign keys

# %% [markdown]
# Instead of only storing foreign keys, it is common to store actual foreign values along with the model's data. For example, each blog comment might include the username in addition to a user id, thus providing easy access to the username without requiring another lookup. When a username changes however, this will now need to be changed in many places in the database. Thus this approach works better when reads are much more common than writes.

# %% [markdown]
# ### Nesting data

# %% [markdown]
# With document databases like MongoDB it is common to put more data in a smaller number of collections. For example, in a blogging application, one might choose to store comments within the blog post document so that with a single retrieval one gets all the comments. Thus in this approach a single document contains all the data you need for a specific task.

# %% [markdown]
# ## Database selection
# One Size Does Not Fit All
# Refer [here](https://perspectives.mvdirona.com/2009/11/one-size-does-not-fit-all/)

# %% [markdown]
# ### Features first

# %% [markdown]
# he feature-first segment is perhaps the simplest to talk about in that there is near universal agreement. After 35 to 40 years, depending upon how you count, Relational Database Management Systems (RDBMSs) are the structured storage system of choice when a feature-rich solution is needed. Common Feature-First workloads are enterprise financial systems, human resources systems, and customer relationship management systems. In even very large enterprises, a single database instance can often support the entire workload and nearly all of these workloads are hosted on non-sharded relational database management systems.
#
#
# Examples of products that meet this objective well include Oracle, SQL Server, DB2, MySQL, PostgreSQL amongst others. And the Amazon Relational Database Service announced last week is a good example of a cloud-based solution. Generally, the feature-first segment use RDBMSs.

# %% [markdown]
# ### Scale first

# %% [markdown]
# The Scale-first segment is considerably less clear and the source of much more debate. Scale-first applications are those that absolutely must scale without bound and being able to do this without restriction is much more important than more features. These applications are exemplified by very high scale web sites such as Facebook, MySpace, Gmail, Yahoo, and Amazon.com. Some of these sites actually do make use of relational databases but many do not. The common theme across all of these services is that scale is more important than features and none of them could possibly run on a single RDBMS. As soon as a single RDBMS instance won’t handle the workload, there are two broad possibilities: 1) shard the application data over a large number of RDBMS systems, or 2) use a highly scalable key-value store. Examples: Voldemort, Ringo, SimpleDB, Ringo, Kai, Dynomite, PNUTS, ThruDB, Hypertable, CouchDB, Cassandra, MemcacheDB.

# %% [markdown]
# ### Simple structure storage

# %% [markdown]
# These are key-value stores where the emphasis is on storing and getting values of arbitrary structure. They generally don't have the features or scalability of other systems. Examples: file systems, MongoDb and Cassandra

# %% [markdown]
# ### Purpose-optimized stores

# %% [markdown]
# These are databases systems built to be good at one thing, like data warehousing. Examples: StreamBase, Vertica, VoltDB, Aster Data, Netezza, Greenplum.

# %%
###### I am done #########
