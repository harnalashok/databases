# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/databases/blob/main/5_logical_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create Logical model from conceptual model

# %%
# Last amended: 18th June, 2024

# %% [markdown]
# ## Develop schema

# %% [markdown]
# 1. Open MySQL WorkBench and login as user ashok. Click on the grey rectangle below:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Click on *File-->New Model* to open modeling operations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Click on *Add Diagram*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Click on the icon to Place a new table and then click inside the workbench.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. You get a table as *table1*. Change its name in the panel below and start adding its columns (by clicking on *Columns* tab):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Two columns added to table. Alos we specify column data type and its contsraints:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Similarly add another table by name of *Courses*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. To create *Many-to-Many* relationship between the two tables first click on the *n:m icon*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. Next click on the headers of the two tables, one after another. A IIIrd table is automatically created.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Create schema code

# %% [markdown]
# Click on *Database-->Forward Enginner*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on *Database-->Forward Engineer* to open the following dialog box. Just enter the name of user: 'ashok' and click on *Next* button and then again *Next* button. You will be asked password of 'ashok'. Supply it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On supplying the password, you get the following Window. Just click on *Next* button.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# On clicking *Next*, you get the complete code for the schema.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the above window, ckick on the button *Copy to Clipboard* and save the code in gedit as an SQL file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
################ I am Done ##########
